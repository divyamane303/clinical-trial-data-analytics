# %%
import pandas as pd

# %%
patients=pd.read_excel('/content/clinical_trials.xlsx',sheet_name='patients')
treatments=pd.read_excel('/content/clinical_trials.xlsx',sheet_name='treatments')
treatments_cut=pd.read_excel('/content/clinical_trials.xlsx',sheet_name='treatments_cut')
adverse_reaction=pd.read_excel('/content/clinical_trials.xlsx',sheet_name='treatments_cut')

# %%
patients_cp=patients.copy()
treatments_cp=treatments.copy()
treatments_cut_cp=treatments_cut.copy()
adverse_reaction_cut_cp=adverse_reaction.copy()

# %%
patients_cp['country']=patients_cp['country'].fillna('United States')

# %%
patients_cp['state']=patients_cp['state'].fillna("CA")

# %%
patients_cp[(patients_cp['state']=='CA')|(patients_cp['state']=='California')]['city'].value_counts()
# Out:
# city
# San Diego            8
# Los Angeles          5
# Sacramento           4
# San Jose             3
# San Francisco        2
# Oakland              2
# Burbank              2
# Rancho California    1
# Morgan Hill          1
# Fremont              1
# Bakersfield          1
# La Mesa              1
# Long Beach           1
# Fresno               1
# Oroville             1
# Newhall              1
# West Los Angeles     1
# Palo Alto            1
# Citrus Heights       1
# Fontana              1
# Santa Ana            1
# Antioch              1
# San Carlos           1
# Santa Cruz           1
# Lakeport             1
# Walnut Creek         1
# Irvine               1
# Fullerton            1
# Palmdale             1
# Sherman Oaks         1
# Diamond Bar          1
# Dublin               1
# Anaheim              1
# San Joaquin          1
# Upland               1
# Redding              1
# Mountain View        1
# Ontario              1
# Lafayette            1
# ...

# %%
patients_cp['city']=patients_cp['city'].fillna('san Diego')

# %%
patients_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       503 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients_cp[patients_cp['city']=='San Diego']['zip_code'].value_counts()
# Out:
# zip_code
# 92101.0    2
# 92103.0    2
# 92123.0    1
# 92111.0    1
# 92109.0    1
# 92073.0    1
# Name: count, dtype: int64

# %%
patients_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       503 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients_cp['zip_code']=patients_cp['zip_code'].fillna('92101.0')

# %%
patients_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
patients_cp['address']=patients_cp['address'].fillna('No Data')

# %%
patients_cp['contact']=patients_cp['contact'].fillna('No Data')

# %%
patients_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
patients_cp
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...

# %%
patients_cp.info()
patients_cp.describe()
patients_cp.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB
# patient_id      0
# assigned_sex    0
# given_name      0
# surname         0
# address         0
# ...

# %%
patients_cp.isnull().sum()
# Out:
# patient_id      0
# assigned_sex    0
# given_name      0
# surname         0
# address         0
# city            0
# state           0
# zip_code        0
# country         0
# contact         0
# birthdate       0
# weight          0
# height          0
# bmi             0
# dtype: int64

# %%
patients_cp.describe()
# Out:
#        patient_id      weight      height         bmi
# count  503.000000  503.000000  503.000000  503.000000
# mean   252.000000  173.434990   66.634195   27.483897
# std    145.347859   33.916741    4.411297    5.276438
# min      1.000000   48.800000   27.000000   17.100000
# 25%    126.500000  149.300000   63.000000   23.300000
# 50%    252.000000  175.300000   67.000000   27.200000
# 75%    377.500000  199.500000   70.000000   31.750000
# max    503.000000  255.900000   79.000000   37.700000

# %%
patients_cp['assigned_sex'].value_counts()
# Out:
# assigned_sex
# male      253
# female    250
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

patients_cp['assigned_sex'].value_counts().plot(kind='bar')

plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution")

plt.show()

# %%
patients_cp['bmi'].describe()
# Out:
# count    503.000000
# mean      27.483897
# std        5.276438
# min       17.100000
# 25%       23.300000
# 50%       27.200000
# 75%       31.750000
# max       37.700000
# Name: bmi, dtype: float64

# %%
print("Average Weight:", patients_cp['weight'].mean())
print("Average Height:", patients_cp['height'].mean())
# Out:
# Average Weight: 173.43499005964213
# Average Height: 66.63419483101391

# %%
patients_cp['birthdate'] = pd.to_datetime(patients_cp['birthdate'])

today = pd.Timestamp('today')

patients_cp['age'] = (today - patients_cp['birthdate']).dt.days // 365

patients_cp[['given_name', 'age']].head()
# Out:
#   given_name  age
# 0        Zoe   49
# 1     Pamela   59
# 2        Jae   46
# 3       Liêm   74
# 4        Tim   98

# %%
def bmi_category(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif bmi < 25:
        return 'Normal'
    elif bmi < 30:
        return 'Overweight'
    else:
        return 'Obese'

patients_cp['bmi_category'] = patients_cp['bmi'].apply(bmi_category)

patients_cp['bmi_category'].value_counts()
# Out:
# bmi_category
# Normal         178
# Obese          177
# Overweight     138
# Underweight     10
# Name: count, dtype: int64

# %%
treatments_cp['hba1c_change'].describe()
# Out:
# count    171.000000
# mean       0.546023
# std        0.279555
# min        0.200000
# 25%        0.340000
# 50%        0.380000
# 75%        0.920000
# max        0.990000
# Name: hba1c_change, dtype: float64

# %%
treatments_cp[['auralin', 'novodra']].sum()
# Out:
# auralin    41u - 48u--33u - 36u--37u - 42u31u - 38u-30u -...
# novodra    -40u - 45u39u - 36u-33u - 29u42u - 44u--54u - ...
# dtype: object

# %%
treatments_cp.sort_values(by='hba1c_change').head()
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 275     albina     zetticci  45u - 51u          -         7.93       7.73
# 70        tosh       jensen          -  51u - 48u         7.93       7.69
# 237    manouck      wubbels  55u - 62u          -         7.66       7.40
# 200    nicolas     ferreira  43u - 51u          -         7.99       7.72
# 156    chidalu  onyekaozulu          -  42u - 41u         7.54       7.27
#
#      hba1c_change
# 275          0.20
# 70           0.24
# 237          0.26
# 200          0.27
# 156          0.27

# %%
treatments_cp['hba1c_change'].mean()
# Out:
# np.float64(0.5460233918128655)

# %%
import matplotlib.pyplot as plt

treatments_cp['hba1c_change'].plot(kind='hist', bins=10)

plt.title("Distribution of HbA1c Change")
plt.xlabel("HbA1c Change")

plt.show()

# %%
merged_data = pd.merge(
    patients_cp,
    treatments_cp,
    on=['given_name', 'surname'],
    how='inner'
)

display(merged_data.head())
# Out:
# Empty DataFrame
# Columns: [patient_id, assigned_sex, given_name, surname, address, city, state, zip_code, country, contact, birthdate, weight, height, bmi, age, bmi_category, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []
#
# [0 rows x 21 columns]

# %%
print(treatments_cp.shape)
print(treatments_cut_cp.shape)
# Out:
# (280, 7)
# (70, 7)

# %%
print(treatments_cp.isnull().sum())

print(treatments_cut_cp.isnull().sum())
# Out:
# given_name        0
# surname           0
# auralin           0
# novodra           0
# hba1c_start       0
# hba1c_end         0
# hba1c_change    109
# dtype: int64
# given_name       0
# surname          0
# auralin          0
# novodra          0
# hba1c_start      0
# hba1c_end        0
# hba1c_change    28
# dtype: int64

# %%
print(treatments_cp.duplicated().sum())

print(treatments_cut_cp.duplicated().sum())
# Out:
# 1
# 0

# %%
treatments_cp.equals(treatments_cut)
# Out:
# False

# %%
patients_cp.drop_duplicates(inplace=True)

treatments_cp.drop_duplicates(inplace=True)

adverse_reaction_cut_cp.drop_duplicates(inplace=True)

# %%
merged_data = pd.merge(
    patients,
    treatments_cut_cp,
    on=['given_name', 'surname'],
    how='inner'
)

# %%
final_data['hba1c_change'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4078/3890258025.py in <cell line: 0>()
# ----> 1 final_data['hba1c_change'].mean()
#
# NameError: name 'final_data' is not defined

# %%
'hba1c_change'
# Out:
# 'hba1c_change'

# %%
final_data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4078/3144297096.py in <cell line: 0>()
# ----> 1 final_data.columns
#
# NameError: name 'final_data' is not defined

# %%
patients_cp.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1          Armstrong    Illinois  61812.0  United States
# 2               York    Nebraska  68467.0  United States
# 3         Woodbridge          NJ   7095.0  United States
# 4             Dothan          AL  36303.0  United States
#
#                                       contact  birthdate  weight  height  \
# 0        951-719-9170ZoeWellish@superrito.com 1976-07-10   121.7      66
# ...

# %%
treatments_cut_cp.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
adverse_reaction_cut_cp.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
merged_data = pd.merge(
    patients_cp,
    treatments_cut_cp,
    on=['given_name', 'surname'],
    how='inner'
)

print(merged_data.head())
# Out:
# Empty DataFrame
# Columns: [patient_id, assigned_sex, given_name, surname, address, city, state, zip_code, country, contact, birthdate, weight, height, bmi, age, bmi_category, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []
#
# [0 rows x 21 columns]

# %%
patients_cp['given_name'] = patients_cp['given_name'].str.strip().str.lower()
patients_cp['surname'] = patients_cp['surname'].str.strip().str.lower()

treatments_cut_cp['given_name'] = treatments_cut_cp['given_name'].str.strip().str.lower()
treatments_cut_cp['surname'] = treatments_cut_cp['surname'].str.strip().str.lower()

# %%
merged_data = pd.merge(
    patients_cp,
    treatments_cut_cp,
    on=['given_name', 'surname'],
    how='inner'
)

print(merged_data.shape)
display(merged_data.head())
# Out:
# (70, 21)
#    patient_id assigned_sex given_name   surname               address  \
# 0           1       female        zoe   wellish  576 Brown Bear Drive
# 1           7       female       mary     adams      3145 Sheila Lane
# 2          25         male      jakob  jakobsen     648 Old Dear Lane
# 3          27       female       ella      lund    1207 Garfield Road
# 4          28         male     joseph    tucker      4982 Wood Street
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1            Burbank          NV  84728.0  United States
# 2        Port Jervis    New York  12771.0  United States
# 3             Peoria          IL  61602.0  United States
# 4             Venice          LA  70091.0  United States
#
#                                       contact  ... weight  height   bmi  age  \
# 0        951-719-9170ZoeWellish@superrito.com  ...  121.7      66  19.6   49
# ...

# %%
final_data = pd.merge(
    merged_data,
    adverse_reaction_cut_cp,
    on=['given_name', 'surname'],
    how='left'
)

display(final_data.head())
# Out:
#    patient_id assigned_sex given_name   surname               address  \
# 0           1       female        zoe   wellish  576 Brown Bear Drive
# 1           7       female       mary     adams      3145 Sheila Lane
# 2          25         male      jakob  jakobsen     648 Old Dear Lane
# 3          27       female       ella      lund    1207 Garfield Road
# 4          28         male     joseph    tucker      4982 Wood Street
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1            Burbank          NV  84728.0  United States
# 2        Port Jervis    New York  12771.0  United States
# 3             Peoria          IL  61602.0  United States
# 4             Venice          LA  70091.0  United States
#
#                                       contact  ...  auralin_x  novodra_x  \
# 0        951-719-9170ZoeWellish@superrito.com  ...          -  33u - 33u
# ...

# %%
[col for col in final_data.columns if 'hba1c' in col]
# Out:
# ['hba1c_start_x',
#  'hba1c_end_x',
#  'hba1c_change_x',
#  'hba1c_start_y',
#  'hba1c_end_y',
#  'hba1c_change_y']

# %%
final_data['hba1c_change_x'].mean()
# Out:
# np.float64(0.5188095238095238)

# %%
final_data['hba1c_change_y'].mean()
# Out:
# np.float64(0.5188095238095238)

# %%
final_data['hba1c_change_x'].mean()
# Out:
# np.float64(0.5188095238095238)

# %%
final_data.groupby('assigned_sex')['hba1c_change_x'].mean()
# Out:
# assigned_sex
# female    0.471250
# male      0.582222
# Name: hba1c_change_x, dtype: float64

# %%
final_data['adverse_reaction_cp'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adverse_reaction_cp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4078/969678166.py in <cell line: 0>()
# ----> 1 final_data['adverse_reaction_cp'].value_counts()
#
# ...

# %%
final_data['adverse_reaction'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adverse_reaction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4078/276008053.py in <cell line: 0>()
# ----> 1 final_data['adverse_reaction'].value_counts()
#
# ...

# %%
[col for col in final_data.columns if 'reaction' in col]
# Out:
# []

# %%
['adverse_reaction_y']
# Out:
# ['adverse_reaction_y']

# %%
final_data['adverse_reaction_y'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adverse_reaction_y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2422/2979877120.py in <cell line: 0>()
# ----> 1 final_data['adverse_reaction_y'].value_counts()
#
# ...

# %%
final_data.columns.tolist()
# Out:
# ['patient_id',
#  'assigned_sex',
#  'given_name',
#  'surname',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'country',
#  'contact',
#  'birthdate',
#  'weight',
#  'height',
#  'bmi',
#  'age',
#  'bmi_category',
#  'auralin_x',
#  'novodra_x',
#  'hba1c_start_x',
#  'hba1c_end_x',
#  'hba1c_change_x',
#  'auralin_y',
#  'novodra_y',
#  'hba1c_start_y',
#  'hba1c_end_y',
#  'hba1c_change_y']

# %%
final_data = pd.merge(
    merged_data,
    adverse_reaction_cut_cp,
    on=['given_name', 'surname'],
    how='left'
)

# %%
final_data.columns.tolist()
# Out:
# ['patient_id',
#  'assigned_sex',
#  'given_name',
#  'surname',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'country',
#  'contact',
#  'birthdate',
#  'weight',
#  'height',
#  'bmi',
#  'age',
#  'bmi_category',
#  'auralin_x',
#  'novodra_x',
#  'hba1c_start_x',
#  'hba1c_end_x',
#  'hba1c_change_x',
#  'auralin_y',
#  'novodra_y',
#  'hba1c_start_y',
#  'hba1c_end_y',
#  'hba1c_change_y']

# %%
adverse_reaction_cut_cp.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
adverse_reaction_cut_cp['given_name'] = adverse_reaction_cut_cp['given_name'].str.strip().str.lower()

adverse_reaction_cut_cp['surname'] = adverse_reaction_cut_cp['surname'].str.strip().str.lower()

# %%
final_data = pd.merge(
    merged_data,
    adverse_reaction_cut_cp,
    on=['given_name', 'surname'],
    how='left'
)

# %%
final_data.columns.tolist()
# Out:
# ['patient_id',
#  'assigned_sex',
#  'given_name',
#  'surname',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'country',
#  'contact',
#  'birthdate',
#  'weight',
#  'height',
#  'bmi',
#  'age',
#  'bmi_category',
#  'auralin_x',
#  'novodra_x',
#  'hba1c_start_x',
#  'hba1c_end_x',
#  'hba1c_change_x',
#  'auralin_y',
#  'novodra_y',
#  'hba1c_start_y',
#  'hba1c_end_y',
#  'hba1c_change_y']

# %%
merged_data = pd.merge(
    patients_cp,
    treatments_cut_cp,
    on=['given_name', 'surname'],
    how='inner'
)

print(merged_data.columns.tolist())
# Out:
# ['patient_id', 'assigned_sex', 'given_name', 'surname', 'address', 'city', 'state', 'zip_code', 'country', 'contact', 'birthdate', 'weight', 'height', 'bmi', 'age', 'bmi_category', 'auralin', 'novodra', 'hba1c_start', 'hba1c_end', 'hba1c_change']

# %%
adverse_reaction_cut_cp['given_name'] = adverse_reaction_cut_cp['given_name'].str.strip().str.lower()

adverse_reaction_cut_cp['surname'] = adverse_reaction_cut_cp['surname'].str.strip().str.lower()

# %%
final_data = pd.merge(
    merged_data,
    adverse_reaction_cut_cp,
    on=['given_name', 'surname'],
    how='left'
)

# %%
final_data.columns.tolist()
# Out:
# ['patient_id',
#  'assigned_sex',
#  'given_name',
#  'surname',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'country',
#  'contact',
#  'birthdate',
#  'weight',
#  'height',
#  'bmi',
#  'age',
#  'bmi_category',
#  'auralin_x',
#  'novodra_x',
#  'hba1c_start_x',
#  'hba1c_end_x',
#  'hba1c_change_x',
#  'auralin_y',
#  'novodra_y',
#  'hba1c_start_y',
#  'hba1c_end_y',
#  'hba1c_change_y']

# %%
adverse_reaction_cut_cp.columns.tolist()
# Out:
# ['given_name',
#  'surname',
#  'auralin',
#  'novodra',
#  'hba1c_start',
#  'hba1c_end',
#  'hba1c_change']

# %%
data = pd.read_excel('/content/clinical_trials.xlsx', sheet_name=None)

adverse_reaction = data['adverse_reaction']

adverse_reaction_cut_cp = adverse_reaction.copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4078/3301144699.py in <cell line: 0>()
#       1 data = pd.read_excel('/content/clinical_trials.xlsx', sheet_name=None)
#       2
# ----> 3 adverse_reaction = data['adverse_reaction']
#       4
#       5 adverse_reaction_cut_cp = adverse_reaction.copy()
#
# KeyError: 'adverse_reaction'

# %%
adverse_reaction = data['adverse_reactions']

adverse_reaction_cut_cp = adverse_reaction.copy()

# %%
adverse_reaction_cut_cp.columns.tolist()
# Out:
# ['given_name', 'surname', 'adverse_reaction']

# %%
adverse_reaction_cut_cp['given_name'] = adverse_reaction_cut_cp['given_name'].str.strip().str.lower()

adverse_reaction_cut_cp['surname'] = adverse_reaction_cut_cp['surname'].str.strip().str.lower()

# %%
final_data = pd.merge(
    merged_data,
    adverse_reaction_cut_cp,
    on=['given_name', 'surname'],
    how='left'
)

# %%
final_data['adverse_reaction'].value_counts()
# Out:
# adverse_reaction
# injection site discomfort    4
# hypoglycemia                 2
# nausea                       1
# cough                        1
# Name: count, dtype: int64

# %%
final_data['adverse_reaction'].value_counts()
# Out:
# adverse_reaction
# injection site discomfort    4
# hypoglycemia                 2
# nausea                       1
# cough                        1
# Name: count, dtype: int64

# %%
final_data['hba1c_change'].mean()
# Out:
# np.float64(0.5188095238095238)

# %%
final_data.groupby('assigned_sex')['hba1c_change_x'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4078/2698887278.py in <cell line: 0>()
# ----> 1 final_data.groupby('assigned_sex')['hba1c_change_x'].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: hba1c_change_x'

# %%
final_data['hba1c_change_x'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hba1c_change_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4078/1858900723.py in <cell line: 0>()
# ----> 1 final_data['hba1c_change_x'].mean()
#
# ...

# %%
[col for col in final_data.columns if 'hba1c' in col]
# Out:
# ['hba1c_start', 'hba1c_end', 'hba1c_change']

# %%
final_data.groupby('assigned_sex')['hba1c_change'].mean()
# Out:
# assigned_sex
# female    0.471250
# male      0.582222
# Name: hba1c_change, dtype: float64

# %%
final_data.groupby('assigned_sex')['hba1c_change'].mean()
# Out:
# assigned_sex
# female    0.471250
# male      0.582222
# Name: hba1c_change, dtype: float64

# %%
final_data['adverse_reaction'].value_counts()
# Out:
# adverse_reaction
# injection site discomfort    4
# hypoglycemia                 2
# nausea                       1
# cough                        1
# Name: count, dtype: int64

# %%
final_data[['bmi', 'hba1c_change']].corr()
# Out:
#                    bmi  hba1c_change
# bmi           1.000000     -0.138492
# hba1c_change -0.138492      1.000000

# %%
import matplotlib.pyplot as plt

final_data['adverse_reaction'].value_counts().plot(kind='bar')

plt.title("Adverse Reactions")
plt.xlabel("Reaction")
plt.ylabel("Count")

plt.show()

# %%
final_data.shape
# Out:
# (70, 22)

# %%
final_data.head()
# Out:
#    patient_id assigned_sex given_name   surname               address  \
# 0           1       female        zoe   wellish  576 Brown Bear Drive
# 1           7       female       mary     adams      3145 Sheila Lane
# 2          25         male      jakob  jakobsen     648 Old Dear Lane
# 3          27       female       ella      lund    1207 Garfield Road
# 4          28         male     joseph    tucker      4982 Wood Street
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1            Burbank          NV  84728.0  United States
# 2        Port Jervis    New York  12771.0  United States
# 3             Peoria          IL  61602.0  United States
# 4             Venice          LA  70091.0  United States
#
#                                       contact  ... height   bmi  age  \
# 0        951-719-9170ZoeWellish@superrito.com  ...     66  19.6   49
# ...

# %%
final_data.isnull().sum()
# Out:
# patient_id           0
# assigned_sex         0
# given_name           0
# surname              0
# address              0
# city                 0
# state                0
# zip_code             0
# country              0
# contact              0
# birthdate            0
# weight               0
# height               0
# bmi                  0
# age                  0
# bmi_category         0
# auralin              0
# novodra              0
# hba1c_start          0
# hba1c_end            0
# hba1c_change        28
# adverse_reaction    62
# dtype: int64

# %%
final_data['hba1c_start'] - final_data['hba1c_end']
# Out:
# 0     0.41
# 1     0.39
# 2     0.45
# 3     0.36
# 4     0.37
#       ...
# 65    0.34
# 66    0.34
# 67    0.47
# 68    0.43
# 69    0.40
# Length: 70, dtype: float64

# %%
final_data['hba1c_change']
# Out:
# 0     0.91
# 1      NaN
# 2     0.95
# 3     0.36
# 4     0.37
#       ...
# 65    0.34
# 66    0.34
# 67     NaN
# 68    0.93
# 69     NaN
# Name: hba1c_change, Length: 70, dtype: float64

# %%
final_data['hba1c_change'].describe()
# Out:
# count    42.000000
# mean      0.518810
# std       0.270719
# min       0.280000
# 25%       0.340000
# 50%       0.370000
# 75%       0.907500
# max       0.970000
# Name: hba1c_change, dtype: float64

# %%
final_data['adverse_reaction'].value_counts()
# Out:
# adverse_reaction
# injection site discomfort    4
# hypoglycemia                 2
# nausea                       1
# cough                        1
# Name: count, dtype: int64

# %%
final_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_data['assigned_sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='assigned_sex'>

# %%
final_data['adverse_reaction'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='adverse_reaction'>

# %%
final_data['hba1c_change'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
final_data.to_csv('final_data.csv', index=False)

# %%
final_data.to_csv('/content/final_data.csv', index=False)

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'clinical_trials.xlsx', 'final_data.csv', 'sample_data']

# %%
'final_data.csv'
# Out:
# 'final_data.csv'

# %%
final_data = final_data.dropna(subset=['adverse_reaction'])

# %%
final_data.to_csv('/content/final_data.csv', index=False)

# %%
import os

os.remove('/content/final_data.csv')

# %%
final_data = final_data.dropna(subset=['adverse_reaction'])

final_data.to_csv('/content/final_data.csv', index=False)
